# %% [markdown]
# # Data Analyst

# %%
# import
import numpy as np
import pandas as pd

# %%
path = r"C:\Users\jalerse\Documents\DataAnalys-Pivot\Data Pivot Party 19012021.xlsx"
df = pd.read_excel(path)
df
# Out:
#      Nomor  User ID            Nama                        Email  \
# 0        1      262  Khalif Radhian       khalif@widyawicara.com
# 1        2      523           Lenni  strawberryveeling@gmail.com
# 2        3      913  Amanda Hambali      Amanda.hambali@pico.con
# 3        4      422   indah Saputra    indah.octavia18@gmail.com
# 4        5      327           Farid        faridfadhil@ymail.com
# ..     ...      ...             ...                          ...
# 953    954      923             NaN     rusdiana@widyawicara.com
# 954    955     1324             NaN     ayukharisma810@gmail.com
# 955    956     1323             NaN         kodonyepit@gmail.com
# 956    957     1328             NaN  rezafebryantara65@gmail.com
# 957    958      987             NaN     asnawimarina96@gmail.com
#
#              Phone           Device UUID      Device Name
# 0     '08166499746                   NaN              NaN
# 1    '085866310399                   NaN              NaN
# ...
